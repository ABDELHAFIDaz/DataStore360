# %%
import pandas as pd
from data_profiling import ProfileReport

df = pd.read_csv("../data/processed/superstore_clean.csv")
df.shape
# Out:
# (9577, 23)

# %%
profile = ProfileReport(df, title="DataStore360 - Rapport de Profiling")
profile.to_file("../reports/rapport_profiling.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
