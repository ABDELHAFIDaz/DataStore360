# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

df = pd.read_csv("../data/raw/store-data-360.csv")
df.shape
# Out:
# (10064, 21)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code Region       Product ID         Category Sub-Category  \
# 0     42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1     42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2     90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3     33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4     33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200       2.0
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775       5.0
# 4                     Eldon Fold 'N Roll Cart System   22.3680       2.0
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.tail()
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 10059    1281  CA-2016-160815    9/5/2016    9/6/2016     First Class
# 10060    7699  CA-2017-151799  12/14/2017  12/18/2017  Standard Class
# 10061    8597  CA-2014-111934    5/5/2014    5/7/2014     First Class
# 10062    4962  CA-2014-156587    3/7/2014    3/8/2014     First Class
# 10063    3998  CA-2015-105627    3/8/2015   3/12/2015  Standard Class
#
#       Customer ID      Customer Name      Segment        Country  \
# 10059    TR-21325       TOBY RITTER      Consumer  United States
# 10060    BF-11170        BEN FERRER   Home Office  United States
# 10061    GD-14590  GIULIETTA DORTCH     Corporate  United States
# 10062    AB-10015                NaN     Consumer  United States
# 10063    DK-12895       DANA KAYDOS      Consumer  United States
#
#                City  ... Postal Code   Region       Product ID  \
# 10059  Cedar Rapids  ...     52402.0  Central  TEC-PH-10003505
# 10060      Lawrence  ...      1841.0     East  OFF-ST-10002790
# 10061     Arlington  ...     22204.0    South  OFF-PA-10000474
# 10062       Seattle  ...     98103.0     West  FUR-CH-10004477
# 10063       Kenosha  ...     53142.0  Central  OFF-AR-10002704
#
#               Category Sub-Category  \
# 10059       Technology       Phones
# 10060  Office Supplies      Storage
# 10061  Office Supplies        Paper
# 10062        Furniture       Chairs
# 10063  Office Supplies          Art
#
#                                      Product Name    Sales  Quantity  \
# 10059                        Geemarc AmpliPOWER60  278.400       3.0
# 10060                   Safco Industrial Shelving   73.850       1.0
# 10061                           Easy-staple paper   35.440       1.0
# 10062  Global Push Button Manager's Chair, Indigo   48.712       1.0
# 10063       Boston 1900 Electric Pencil Sharpener   14.980       1.0
#
#        Discount   Profit
# 10059       0.0  80.7360
# 10060       0.0   2.2155
# 10061       0.0  16.6568
# 10062       0.2   5.4801
# 10063       0.0   4.4940
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10064 entries, 0 to 10063
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         10064 non-null  int64
#  1   Order ID       10064 non-null  object
#  2   Order Date     10064 non-null  object
#  3   Ship Date      9963 non-null   object
#  4   Ship Mode      9763 non-null   object
#  5   Customer ID    10064 non-null  object
#  6   Customer Name  9713 non-null   object
#  7   Segment        10064 non-null  object
#  8   Country        10064 non-null  object
#  9   City           10064 non-null  object
#  10  State          10064 non-null  object
#  11  Postal Code    9864 non-null   object
#  12  Region         10064 non-null  object
#  13  Product ID     10064 non-null  object
#  14  Category       10064 non-null  object
#  15  Sub-Category   10064 non-null  object
#  16  Product Name   10064 non-null  object
#  17  Sales          9863 non-null   float64
#  18  Quantity       9865 non-null   float64
#  19  Discount       10064 non-null  float64
#  20  Profit         10064 non-null  float64
# dtypes: float64(4), int64(1), object(16)
# memory usage: 1.6+ MB

# %%
df.describe(include="all")
# Out:
#               Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# count   10064.000000           10064      10064        9963            9763
# unique           NaN            5009       1495        1334               4
# top              NaN  CA-2017-100111   9/5/2016  12/16/2015  Standard Class
# freq             NaN              14         39          35            5822
# mean     4994.397059             NaN        NaN         NaN             NaN
# std      2885.848580             NaN        NaN         NaN             NaN
# min         1.000000             NaN        NaN         NaN             NaN
# 25%      2496.750000             NaN        NaN         NaN             NaN
# 50%      4989.500000             NaN        NaN         NaN             NaN
# 75%      7494.250000             NaN        NaN         NaN             NaN
# max      9994.000000             NaN        NaN         NaN             NaN
#
#        Customer ID  Customer Name   Segment        Country           City  \
# count        10064           9713     10064          10064          10064
# unique         793            810         6              1            633
# top       WB-21850  William Brown  Consumer  United States  New York City
# freq            38             36      5163          10064            896
# mean           NaN            NaN       NaN            NaN            NaN
# std            NaN            NaN       NaN            NaN            NaN
# min            NaN            NaN       NaN            NaN            NaN
# 25%            NaN            NaN       NaN            NaN            NaN
# 50%            NaN            NaN       NaN            NaN            NaN
# 75%            NaN            NaN       NaN            NaN            NaN
# max            NaN            NaN       NaN            NaN            NaN
#
#         ... Postal Code Region       Product ID         Category Sub-Category  \
# count   ...        9864  10064            10064            10064        10064
# unique  ...         705      4             1862                6           17
# top     ...     10035.0   West  OFF-PA-10001970  Office Supplies      Binders
# freq    ...         259   3224               19             5942         1532
# mean    ...         NaN    NaN              NaN              NaN          NaN
# std     ...         NaN    NaN              NaN              NaN          NaN
# min     ...         NaN    NaN              NaN              NaN          NaN
# 25%     ...         NaN    NaN              NaN              NaN          NaN
# 50%     ...         NaN    NaN              NaN              NaN          NaN
# 75%     ...         NaN    NaN              NaN              NaN          NaN
# max     ...         NaN    NaN              NaN              NaN          NaN
#
#              Product Name         Sales     Quantity      Discount  \
# count               10064  9.863000e+03  9865.000000  10064.000000
# unique               1850           NaN          NaN           NaN
# top     Easy-staple paper           NaN          NaN           NaN
# freq                   48           NaN          NaN           NaN
# mean                  NaN  1.950322e+03     3.780233      0.157501
# std                   NaN  4.410673e+04     2.240134      0.210586
# min                   NaN  4.440000e-01    -5.000000      0.000000
# 25%                   NaN  1.729000e+01     2.000000      0.000000
# 50%                   NaN  5.450000e+01     3.000000      0.200000
# 75%                   NaN  2.107600e+02     5.000000      0.200000
# max                   NaN  1.131924e+06    14.000000      1.500000
#
#               Profit
# count   10064.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       28.571309
# std       233.509461
# min     -6599.978000
# 25%         1.724800
# 50%         8.643600
# 75%        29.331600
# max      8399.976000
#
# [11 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# Row ID             0
# Order ID           0
# Order Date         0
# Ship Date        101
# Ship Mode        301
# Customer ID        0
# Customer Name    351
# Segment            0
# Country            0
# City               0
# State              0
# Postal Code      200
# Region             0
# Product ID         0
# Category           0
# Sub-Category       0
# Product Name       0
# Sales            201
# Quantity         199
# Discount           0
# Profit             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(34)

# %%
df['Row ID'].duplicated().sum()
# Out:
# np.int64(70)

# %%
dupe_ids = df[df["Row ID"].duplicated(keep=False)].sort_values("Row ID")
dupe_ids.head(20)
# Out:
#        Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 35         36  CA-2016-117590   12/8/2016  12/10/2016     First Class
# 10030      36  CA-2016-117590   12/8/2016  12/10/2016     First Class
# 9997       40  CA-2015-117415  12/27/2015  12/31/2015  Standard Class
# 39         40  CA-2015-117415  12/27/2015  12/31/2015  Standard Class
# 65         66  CA-2015-135545  11/24/2015  11/30/2015  Standard Class
# 10045      66  CA-2015-135545  2015-11-24  11/30/2015  Standard Class
# 10019     108  CA-2017-119004  11/23/2017  11/28/2017  Standard Class
# 107       108  CA-2017-119004  11/23/2017  11/28/2017  Standard Class
# 360       361  CA-2017-155698    3/8/2017   3/11/2017     First Class
# 10040     361  CA-2017-155698    3/8/2017   3/11/2017     First Class
# 10002     501  US-2016-105578   5/30/2016    6/4/2016  Standard Class
# 500       501  US-2016-105578   5/30/2016    6/4/2016  Standard Class
# 639       640  CA-2016-115917   5/20/2016   5/25/2016  Standard Class
# 10054     640  CA-2016-115917   5/20/2016   5/25/2016  Standard Class
# 668       669  CA-2014-156314  12/24/2014  12/26/2014     First Class
# 10015     669  CA-2014-156314  12/24/2014  12/26/2014     First Class
# 10008     714  US-2017-100048  2017-05-19   5/24/2017  Standard Class
# 713       714  US-2017-100048  2017-05-19   5/24/2017  Standard Class
# 10023     734  CA-2017-131954   1/21/2017   1/25/2017  Standard Class
# 733       734  CA-2017-131954   1/21/2017   1/25/2017  Standard Class
#
#       Customer ID  Customer Name      Segment        Country          City  \
# 35       GH-14485            NaN    Corporate  United States    Richardson
# 10030    GH-14485            NaN    Corporate  United States    Richardson
# 9997     SN-20710            NaN  Home Office  United States       Houston
# 39       SN-20710            NaN  Home Office  United States       Houston
# 65       KM-16720   Kunst Miller     Consumer  United States   Los Angeles
# 10045    KM-16720  KUNST MILLER      Consumer  United States   Los Angeles
# 10019    JM-15250            NaN     Consumer  United States     Charlotte
# 107      JM-15250            NaN     Consumer  United States     Charlotte
# 360      VB-21745            NaN    Corporate  United States      Columbus
# 10040    VB-21745            NaN    Corporate  United States      Columbus
# 10002    MY-17380            NaN    Corporate  United States        Parker
# 500      MY-17380            NaN    Corporate  United States        Parker
# 639      RB-19465   Rick Bensley  Home Office  United States       Vallejo
# 10054    RB-19465  RICK BENSLEY   Home Office  United States       Vallejo
# 668      RP-19390            NaN     Consumer  United States     Cleveland
# 10015    RP-19390            NaN     Consumer  United States     Cleveland
# 10008    RS-19765            NaN    Corporate  United States  Mount Vernon
# 713      RS-19765            NaN    Corporate  United States  Mount Vernon
# 10023    DS-13030            NaN   Home Ofice  United States       Seattle
# 733      DS-13030            NaN  Home Office  United States       Seattle
#
#        ... Postal Code   Region       Product ID         Category  \
# 35     ...     75080.0  Central  TEC-PH-10004977       Technology
# 10030  ...     75080.0  Central  TEC-PH-10004977       Technology
# 9997   ...     77041.0  Central  FUR-CH-10004218        Furniture
# 39     ...     77041.0  Central  FUR-CH-10004218        Furniture
# 65     ...     90004.0     West  FUR-FU-10000397        Furniture
# 10045  ...     90004.0     West  FUR-FU-10000397        Furniture
# 10019  ...     28205.0    South  TEC-PH-10002844       Technology
# 107    ...     28205.0    South  TEC-PH-10002844       Technology
# 360    ...     31907.0    South  OFF-LA-10001158  Office Supplies
# 10040  ...     31907.0    South  OFF-LA-10001158  Office Supplies
# 10002  ...     80134.0     West  OFF-BI-10001670  Office Supplies
# 500    ...     80134.0     West  OFF-BI-10001670  Office Supplies
# 639    ...     94591.0     West  OFF-BI-10004728  Office Supplies
# 10054  ...     94591.0     West  OFF-BI-10004728  Office Supplies
# 668    ...     44105.0     East  FUR-FU-10003096        Furniture
# 10015  ...     44105.0     East  FUR-FU-10003096        Furniture
# 10008  ...     10550.0     East  TEC-PH-10003012       Technology
# 713    ...     10550.0     East  TEC-PH-10003012       Technology
# 10023  ...     98115.0     West  TEC-AC-10003610       Technology
# 733    ...     98115.0     West  TEC-AC-10003610       Technology
#
#       Sub-Category                                       Product Name  \
# 35          Phones                                        GE 30524EE4
# 10030       Phones                                        GE 30524EE4
# 9997        Chairs           Global Fabric Manager's Chair, Dark Gray
# 39          Chairs           Global Fabric Manager's Chair, Dark Gray
# 65     Furnishings                        Luxo Economy Swing Arm Lamp
# 10045  Furnishings                        Luxo Economy Swing Arm Lamp
# 10019       Phones                Speck Products Candyshell Flip Case
# 107         Phones                Speck Products Candyshell Flip Case
# 360         Labels  Avery Address/Shipping Labels for Typewriters,...
# 10040       Labels  Avery Address/Shipping Labels for Typewriters,...
# 10002      Binders                       Vinyl Sectional Post Binders
# 500        Binders                       Vinyl Sectional Post Binders
# 639        Binders  Wilson Jones Turn Tabs Binder Tool for Ring Bi...
# 10054      Binders  Wilson Jones Turn Tabs Binder Tool for Ring Bi...
# 668    Furnishings          Master Giant Foot Doorstop, Safety Yellow
# 10015  Furnishings          Master Giant Foot Doorstop, Safety Yellow
# 10008       Phones   Nortel Meridian M3904 Professional Digital phone
# 713         Phones   Nortel Meridian M3904 Professional Digital phone
# 10023  Accessories                    Logitech Illuminated - Keyboard
# 733    Accessories                    Logitech Illuminated - Keyboard
#
#           Sales  Quantity  Discount    Profit
# 35     1097.544       7.0       0.2  123.4737
# 10030  1097.544       7.0       0.2  123.4737
# 9997    212.058       3.0       0.3  -15.1470
# 39      212.058       3.0       0.3  -15.1470
# 65       79.760       4.0       0.0   22.3328
# 10045    79.760       4.0       0.0   22.3328
# 10019    27.992       1.0       0.2    2.0994
# 107      27.992       1.0       0.2    2.0994
# 360      20.700       2.0       0.0    9.9360
# 10040    20.700       2.0       0.0    9.9360
# 10002    22.620       2.0       0.7  -15.0800
# 500      22.620       2.0       0.7  -15.0800
# 639      15.424       4.0       0.2    5.0128
# 10054    15.424       4.0       0.2    5.0128
# 668      30.360       5.0       0.2    8.7285
# 10015    30.360       5.0       0.2    8.7285
# 10008   307.980       2.0       0.0   89.3142
# 713     307.980       2.0       0.0   89.3142
# 10023       NaN       3.0       0.0   86.3856
# 733         NaN       3.0       0.0   86.3856
#
# [20 rows x 21 columns]

# %%
for col in ["Segment", "Ship Mode", "Category", "Sub-Category", "Region", "State"]:
    print(f"------{col}------")
    print(df[col].unique())
    print()
# Out:
# ------Segment------
# ['Consumer' 'Corporate' 'Home Office' 'Home Ofice' 'Consumerr'
#  'Corporrate']
#
# ------Ship Mode------
# ['Second Class' 'Standard Class' nan 'First Class' 'Same Day']
#
# ------Category------
# ['Furniture' 'Office Supplies' 'Technology' 'office supplies' 'furniture'
#  'technology']
#
# ------Sub-Category------
# ['Bookcases' 'Chairs' 'Labels' 'Tables' 'Storage' 'Furnishings' 'Art'
#  'Phones' 'Binders' 'Appliances' 'Paper' 'Accessories' 'Envelopes'
#  'Fasteners' 'Supplies' 'Machines' 'Copiers']
#
# ------Region------
# ['South' 'West' 'Central' 'East']
#
# ------State------
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' '  Pennsylvania  '
#  'Illinois' 'Minnesota' 'Michigan' 'Delaware' 'Indiana' 'New York'
#  'Arizona' 'Virginia' 'Tennessee' 'Alabama' 'South Carolina' 'Oregon'
#  'Colorado' '  New York  ' 'Iowa' 'Ohio' '  Delaware  ' '  Arizona  '
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' '  Louisiana  '
#  'Connecticut' '  Texas  ' 'New Jersey' '  Ohio  ' 'Massachusetts'
#  'Georgia' 'Nevada' 'Rhode Island' '  Kentucky  ' 'Mississippi' 'Arkansas'
#  'Montana' '  California  ' '  Mississippi  ' '  Michigan  '
#  'New Hampshire' '  New Hampshire  ' 'Maryland' 'District of Columbia'
#  '  New Jersey  ' '  Florida  ' '  Virginia  ' '  Rhode Island  '
#  '  Wisconsin  ' '  Washington  ' '  Illinois  ' '  North Carolina  '
#  'Kansas' '  Missouri  ' '  Alabama  ' '  Massachusetts  ' 'Vermont'
#  'Maine' 'South Dakota' '  Maryland  ' '  Utah  ' '  New Mexico  ' 'Idaho'
#  'North Dakota' '  Georgia  ' '  Tennessee  ' '  Colorado  ' '  Indiana  '
#  '  Kansas  ' '  Oregon  ' 'Wyoming' '  Idaho  ' '  Arkansas  '
#  '  Connecticut  ' 'West Virginia' '  Montana  ' '  Iowa  ']

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 14))

sns.histplot(df["Sales"], bins=50, ax=axes[0, 0]).set_title("Sales Distribution")
sns.histplot(df["Profit"], bins=50, ax=axes[0, 1]).set_title("Profit Distribution")
sns.histplot(df["Quantity"], bins=20, ax=axes[1, 0]).set_title("Quantity Distribution")
sns.histplot(df["Discount"], bins=20, ax=axes[1, 1]).set_title("Discount Distribution")

plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(data=df, x="Category", y="Sales").set_title('Sales Distribution by Category')
plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
category_sales.plot(kind="bar")
plt.title("Total Sales by Category")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values()

plt.figure(figsize=(8, 5))
region_sales.plot(kind="bar", color="teal")
plt.title("Total Sales by Region")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %%
segment_sales = df.groupby("Segment")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8, 5))
segment_sales.plot(kind="bar", color="orange")
plt.title("Total Sales by Customer Segment")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %%
corr = df[["Sales", "Quantity", "Discount", "Profit"]].corr()

plt.figure(figsize=(6, 5))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
sns.boxplot(df['Sales'])
plt.show()
